# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import f1_score

# %%
train_set=pd.read_csv('train_jan.csv')
test_set=pd.read_csv('test_jan.csv')

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Loan_ID                  164309 non-null  int64
#  1   Loan_Amount_Requested    164309 non-null  object
#  2   Length_Employed          156938 non-null  object
#  3   Home_Owner               138960 non-null  object
#  4   Annual_Income            139207 non-null  float64
#  5   Income_Verified          164309 non-null  object
#  6   Purpose_Of_Loan          164309 non-null  object
#  7   Debt_To_Income           164309 non-null  float64
#  8   Inquiries_Last_6Mo       164309 non-null  int64
#  9   Months_Since_Deliquency  75930 non-null   float64
#  10  Number_Open_Accounts     164309 non-null  int64
#  11  Total_Accounts           164309 non-null  int64
#  12  Gender                   164309 non-null  object
#  13  Interest_Rate            164309 non-null  int64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 17.6+ MB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109541 entries, 0 to 109540
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Loan_ID                  109541 non-null  int64
#  1   Loan_Amount_Requested    109541 non-null  object
#  2   Length_Employed          104605 non-null  object
#  3   Home_Owner               92830 non-null   object
#  4   Annual_Income            92643 non-null   float64
#  5   Income_Verified          109541 non-null  object
#  6   Purpose_Of_Loan          109541 non-null  object
#  7   Debt_To_Income           109541 non-null  float64
#  8   Inquiries_Last_6Mo       109541 non-null  int64
#  9   Months_Since_Deliquency  50682 non-null   float64
#  10  Number_Open_Accounts     109541 non-null  int64
#  11  Total_Accounts           109541 non-null  int64
#  12  Gender                   109541 non-null  object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 10.9+ MB

# %%
test_set_loan=test_set.iloc[:,0]

# %%
train_set.isnull().sum()
# Out:
# Loan_ID                        0
# Loan_Amount_Requested          0
# Length_Employed             7371
# Home_Owner                 25349
# Annual_Income              25102
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency    88379
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# dtype: int64

# %%
train_set.head(20)
# Out:
#      Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0   10000001                 7,000        < 1 year       Rent        68000.0
# 1   10000002                30,000         4 years   Mortgage            NaN
# 2   10000003                24,725         7 years   Mortgage        75566.4
# 3   10000004                16,000        < 1 year        NaN        56160.0
# 4   10000005                17,000         8 years        Own        96000.0
# 5   10000006                 4,500         2 years       Rent        30000.0
# 6   10000007                18,075         4 years       Rent        85000.0
# 7   10000008                15,000        < 1 year       Rent       115000.0
# 8   10000009                 6,300       10+ years       Rent            NaN
# 9   10000010                30,000       10+ years        Own       163000.0
# 10  10000011                11,700       10+ years   Mortgage        62000.0
# 11  10000012                15,000       10+ years       Rent        70000.0
# 12  10000013                 7,200       10+ years       Rent        55000.0
# 13  10000014                15,000       10+ years   Mortgage            NaN
# 14  10000015                 6,700       10+ years   Mortgage        16000.0
# 15  10000016                35,000         4 years       Rent       101000.0
# 16  10000017                20,800       10+ years   Mortgage            NaN
# 17  10000018                19,925       10+ years       Rent        50000.0
# 18  10000019                25,000       10+ years       Rent        62000.0
# 19  10000020                 6,000          1 year        Own        20000.0
#
#              Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0               not verified                 car           18.37
# 1          VERIFIED - income  debt_consolidation           14.93
# 2   VERIFIED - income source  debt_consolidation           15.88
# 3   VERIFIED - income source  debt_consolidation           14.34
# 4   VERIFIED - income source  debt_consolidation           22.17
# 5   VERIFIED - income source         credit_card           10.88
# 6          VERIFIED - income  debt_consolidation            5.65
# 7          VERIFIED - income  debt_consolidation            7.97
# 8               not verified  debt_consolidation           16.12
# 9          VERIFIED - income  debt_consolidation           11.13
# 10         VERIFIED - income  debt_consolidation           30.91
# 11              not verified         credit_card            8.95
# 12  VERIFIED - income source  debt_consolidation           31.25
# 13  VERIFIED - income source  debt_consolidation           21.03
# 14  VERIFIED - income source         credit_card           14.70
# 15         VERIFIED - income         credit_card           15.24
# 16  VERIFIED - income source  debt_consolidation           10.50
# 17  VERIFIED - income source  debt_consolidation           37.28
# 18         VERIFIED - income         credit_card           13.72
# 19  VERIFIED - income source  debt_consolidation           12.67
#
#     Inquiries_Last_6Mo  Months_Since_Deliquency  Number_Open_Accounts  \
# 0                    0                      NaN                     9
# 1                    0                     17.0                    12
# 2                    0                      NaN                    12
# 3                    3                      NaN                    16
# 4                    1                      NaN                    19
# 5                    1                      NaN                    12
# 6                    0                      NaN                     9
# 7                    1                     16.0                    25
# 8                    3                      NaN                     8
# 9                    0                      NaN                    24
# 10                   0                      NaN                     8
# 11                   0                      NaN                     7
# 12                   0                     68.0                     5
# 13                   0                      NaN                     9
# 14                   0                     13.0                    20
# 15                   0                      NaN                    10
# 16                   1                      6.0                     9
# 17                   1                      NaN                    15
# 18                   0                     64.0                     6
# 19                   2                      NaN                     5
#
#     Total_Accounts  Gender  Interest_Rate
# 0               14  Female              1
# 1               24  Female              3
# 2               16    Male              3
# 3               22    Male              3
# 4               30  Female              1
# 5               15    Male              3
# 6               12    Male              3
# 7               31  Female              2
# 8                9  Female              3
# 9               43    Male              1
# 10              22    Male              2
# 11              13    Male              2
# 12              16    Male              2
# 13              14    Male              2
# 14              43    Male              2
# 15              17  Female              3
# 16              28    Male              3
# 17              31    Male              2
# 18              26  Female              3
# 19              12    Male              3

# %%
train_set=train_set.drop('Loan_ID',axis=1)
test_set=test_set.drop('Loan_ID',axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
train_set['Length_Employed'].fillna(method='pad',inplace=True)
test_set['Length_Employed'].fillna(method='pad',inplace=True)

# %%
train_set['Home_Owner'].fillna(method='pad',inplace=True)
test_set['Home_Owner'].fillna(method='pad',inplace=True)

# %%
train_set.isnull().sum()
# Out:
# Loan_Amount_Requested          0
# Length_Employed                0
# Home_Owner                     0
# Annual_Income              25102
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency    88379
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# dtype: int64

# %%
train_set['Annual_Income'].fillna(train_set['Annual_Income'].median(),inplace=True)
test_set['Annual_Income'].fillna(test_set['Annual_Income'].median(),inplace=True)

# %%
train_set.isnull().sum()
# Out:
# Loan_Amount_Requested          0
# Length_Employed                0
# Home_Owner                     0
# Annual_Income                  0
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency    88379
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# dtype: int64

# %%
train_set['Gender']=le.fit_transform(train_set['Gender'])
test_set['Gender']=le.fit_transform(test_set['Gender'])

# %%
train_set.head(20)
# Out:
#    Loan_Amount_Requested Length_Employed Home_Owner  Annual_Income  \
# 0                  7,000        < 1 year       Rent        68000.0
# 1                 30,000         4 years   Mortgage        63000.0
# 2                 24,725         7 years   Mortgage        75566.4
# 3                 16,000        < 1 year   Mortgage        56160.0
# 4                 17,000         8 years        Own        96000.0
# 5                  4,500         2 years       Rent        30000.0
# 6                 18,075         4 years       Rent        85000.0
# 7                 15,000        < 1 year       Rent       115000.0
# 8                  6,300       10+ years       Rent        63000.0
# 9                 30,000       10+ years        Own       163000.0
# 10                11,700       10+ years   Mortgage        62000.0
# 11                15,000       10+ years       Rent        70000.0
# 12                 7,200       10+ years       Rent        55000.0
# 13                15,000       10+ years   Mortgage        63000.0
# 14                 6,700       10+ years   Mortgage        16000.0
# 15                35,000         4 years       Rent       101000.0
# 16                20,800       10+ years   Mortgage        63000.0
# 17                19,925       10+ years       Rent        50000.0
# 18                25,000       10+ years       Rent        62000.0
# 19                 6,000          1 year        Own        20000.0
#
#              Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0               not verified                 car           18.37
# 1          VERIFIED - income  debt_consolidation           14.93
# 2   VERIFIED - income source  debt_consolidation           15.88
# 3   VERIFIED - income source  debt_consolidation           14.34
# 4   VERIFIED - income source  debt_consolidation           22.17
# 5   VERIFIED - income source         credit_card           10.88
# 6          VERIFIED - income  debt_consolidation            5.65
# 7          VERIFIED - income  debt_consolidation            7.97
# 8               not verified  debt_consolidation           16.12
# 9          VERIFIED - income  debt_consolidation           11.13
# 10         VERIFIED - income  debt_consolidation           30.91
# 11              not verified         credit_card            8.95
# 12  VERIFIED - income source  debt_consolidation           31.25
# 13  VERIFIED - income source  debt_consolidation           21.03
# 14  VERIFIED - income source         credit_card           14.70
# 15         VERIFIED - income         credit_card           15.24
# 16  VERIFIED - income source  debt_consolidation           10.50
# 17  VERIFIED - income source  debt_consolidation           37.28
# 18         VERIFIED - income         credit_card           13.72
# 19  VERIFIED - income source  debt_consolidation           12.67
#
#     Inquiries_Last_6Mo  Months_Since_Deliquency  Number_Open_Accounts  \
# 0                    0                      NaN                     9
# 1                    0                     17.0                    12
# 2                    0                      NaN                    12
# 3                    3                      NaN                    16
# 4                    1                      NaN                    19
# 5                    1                      NaN                    12
# 6                    0                      NaN                     9
# 7                    1                     16.0                    25
# 8                    3                      NaN                     8
# 9                    0                      NaN                    24
# 10                   0                      NaN                     8
# 11                   0                      NaN                     7
# 12                   0                     68.0                     5
# 13                   0                      NaN                     9
# 14                   0                     13.0                    20
# 15                   0                      NaN                    10
# 16                   1                      6.0                     9
# 17                   1                      NaN                    15
# 18                   0                     64.0                     6
# 19                   2                      NaN                     5
#
#     Total_Accounts  Gender  Interest_Rate
# 0               14       0              1
# 1               24       0              3
# 2               16       1              3
# 3               22       1              3
# 4               30       0              1
# 5               15       1              3
# 6               12       1              3
# 7               31       0              2
# 8                9       0              3
# 9               43       1              1
# 10              22       1              2
# 11              13       1              2
# 12              16       1              2
# 13              14       1              2
# 14              43       1              2
# 15              17       0              3
# 16              28       1              3
# 17              31       1              2
# 18              26       0              3
# 19              12       1              3

# %%
train_set_income=pd.get_dummies(train_set['Income_Verified'],drop_first=True)
test_set_income=pd.get_dummies(test_set['Income_Verified'],drop_first=True)

# %%
train_set=pd.concat([train_set,train_set_income],axis=1)
test_set=pd.concat([test_set,test_set_income],axis=1)

# %%
test_set=test_set.drop('Income_Verified',axis=1)
train_set=train_set.drop('Income_Verified',axis=1)

# %%
train_set_home=pd.get_dummies(train_set['Home_Owner'],drop_first=True)
test_set_home=pd.get_dummies(test_set['Home_Owner'],drop_first=True)
train_set_purpose=pd.get_dummies(train_set['Purpose_Of_Loan'],drop_first=True)
test_set_purpose=pd.get_dummies(test_set['Purpose_Of_Loan'],drop_first=True)

# %%
train_set=pd.concat([train_set,train_set_home],axis=1)
test_set=pd.concat([test_set,test_set_home],axis=1)

# %%
train_set=pd.concat([train_set,train_set_purpose],axis=1)
test_set=pd.concat([test_set,test_set_purpose],axis=1)

# %%
test_set=test_set.drop('Home_Owner',axis=1)
train_set=train_set.drop('Home_Owner',axis=1)
test_set=test_set.drop('Purpose_Of_Loan',axis=1)
train_set=train_set.drop('Purpose_Of_Loan',axis=1)

# %%
train_set.describe()
# Out:
#        Annual_Income  Debt_To_Income  Inquiries_Last_6Mo  \
# count   1.643090e+05   164309.000000       164309.000000
# mean    7.175284e+04       17.207189            0.781698
# std     5.569855e+04        7.845083            1.034747
# min     4.000000e+03        0.000000            0.000000
# 25%     4.860000e+04       11.370000            0.000000
# 50%     6.300000e+04       16.840000            0.000000
# 75%     8.200000e+04       22.780000            1.000000
# max     7.500000e+06       39.990000            8.000000
#
#        Months_Since_Deliquency  Number_Open_Accounts  Total_Accounts  \
# count             75930.000000         164309.000000   164309.000000
# mean                 34.229356             11.193818       25.067665
# std                  21.761180              4.991813       11.583067
# min                   0.000000              0.000000        2.000000
# 25%                  16.000000              8.000000       17.000000
# 50%                  31.000000             10.000000       23.000000
# 75%                  50.000000             14.000000       32.000000
# max                 180.000000             76.000000      156.000000
#
#               Gender  Interest_Rate  VERIFIED - income source   not verified  \
# count  164309.000000  164309.000000             164309.000000  164309.000000
# mean        0.713144       2.158951                  0.322654       0.315704
# std         0.452295       0.738364                  0.467493       0.464797
# min         0.000000       1.000000                  0.000000       0.000000
# 25%         0.000000       2.000000                  0.000000       0.000000
# 50%         1.000000       2.000000                  0.000000       0.000000
# 75%         1.000000       3.000000                  1.000000       1.000000
# max         1.000000       3.000000                  1.000000       1.000000
#
#        ...  home_improvement          house  major_purchase        medical  \
# count  ...     164309.000000  164309.000000   164309.000000  164309.000000
# mean   ...          0.056412       0.004705        0.020906       0.009379
# std    ...          0.230716       0.068428        0.143069       0.096389
# min    ...          0.000000       0.000000        0.000000       0.000000
# 25%    ...          0.000000       0.000000        0.000000       0.000000
# 50%    ...          0.000000       0.000000        0.000000       0.000000
# 75%    ...          0.000000       0.000000        0.000000       0.000000
# max    ...          1.000000       1.000000        1.000000       1.000000
#
#               moving          other  renewable_energy  small_business  \
# count  164309.000000  164309.000000     164309.000000   164309.000000
# mean        0.005928       0.050795          0.000749        0.014558
# std         0.076764       0.219579          0.027350        0.119775
# min         0.000000       0.000000          0.000000        0.000000
# 25%         0.000000       0.000000          0.000000        0.000000
# 50%         0.000000       0.000000          0.000000        0.000000
# 75%         0.000000       0.000000          0.000000        0.000000
# max         1.000000       1.000000          1.000000        1.000000
#
#             vacation        wedding
# count  164309.000000  164309.000000
# mean        0.005094       0.005039
# std         0.071191       0.070809
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max         1.000000       1.000000
#
# [8 rows x 31 columns]

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Loan_Amount_Requested     164309 non-null  object
#  1   Length_Employed           164309 non-null  object
#  2   Annual_Income             164309 non-null  float64
#  3   Debt_To_Income            164309 non-null  float64
#  4   Inquiries_Last_6Mo        164309 non-null  int64
#  5   Months_Since_Deliquency   75930 non-null   float64
#  6   Number_Open_Accounts      164309 non-null  int64
#  7   Total_Accounts            164309 non-null  int64
#  8   Gender                    164309 non-null  int32
#  9   Interest_Rate             164309 non-null  int64
#  10  VERIFIED - income source  164309 non-null  uint8
#  11  not verified              164309 non-null  uint8
#  12  None                      164309 non-null  uint8
#  13  Other                     164309 non-null  uint8
#  14  Own                       164309 non-null  uint8
#  15  Rent                      164309 non-null  uint8
#  16  None                      164309 non-null  uint8
#  17  Other                     164309 non-null  uint8
#  18  Own                       164309 non-null  uint8
#  19  Rent                      164309 non-null  uint8
#  20  credit_card               164309 non-null  uint8
#  21  debt_consolidation        164309 non-null  uint8
#  22  educational               164309 non-null  uint8
#  23  home_improvement          164309 non-null  uint8
#  24  house                     164309 non-null  uint8
#  25  major_purchase            164309 non-null  uint8
#  26  medical                   164309 non-null  uint8
#  27  moving                    164309 non-null  uint8
#  28  other                     164309 non-null  uint8
#  29  renewable_energy          164309 non-null  uint8
#  30  small_business            164309 non-null  uint8
#  31  vacation                  164309 non-null  uint8
#  32  wedding                   164309 non-null  uint8
# dtypes: float64(3), int32(1), int64(4), object(2), uint8(23)
# memory usage: 15.5+ MB

# %%
train_set['deliq'] = train_set['Months_Since_Deliquency'].apply(lambda x: 1 if x>=0.0 else 0)

# %%
test_set['deliq'] = test_set['Months_Since_Deliquency'].apply(lambda x: 0 if x>=0.0 else 0)

# %%
train_set['Months_Since_Deliquency'] = train_set['Months_Since_Deliquency'].apply(lambda x: x if x>=0.0 else 0)
test_set['Months_Since_Deliquency'] = test_set['Months_Since_Deliquency'].apply(lambda x: x if x>=0.0 else 0)

# %%
train_set_length=pd.get_dummies(train_set['Length_Employed'],drop_first=True)
test_set_length=pd.get_dummies(test_set['Length_Employed'],drop_first=True)
train_set=pd.concat([train_set,train_set_length],axis=1)
test_set=pd.concat([test_set,test_set_length],axis=1)
test_set=test_set.drop('Length_Employed',axis=1)
train_set=train_set.drop('Length_Employed',axis=1)

# %%
train_set_Y=train_set['Interest_Rate']

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Loan_Amount_Requested     164309 non-null  object
#  1   Annual_Income             164309 non-null  float64
#  2   Debt_To_Income            164309 non-null  float64
#  3   Inquiries_Last_6Mo        164309 non-null  int64
#  4   Months_Since_Deliquency   75930 non-null   float64
#  5   Number_Open_Accounts      164309 non-null  int64
#  6   Total_Accounts            164309 non-null  int64
#  7   Gender                    164309 non-null  int32
#  8   Interest_Rate             164309 non-null  int64
#  9   VERIFIED - income source  164309 non-null  uint8
#  10  not verified              164309 non-null  uint8
#  11  None                      164309 non-null  uint8
#  12  Other                     164309 non-null  uint8
#  13  Own                       164309 non-null  uint8
#  14  Rent                      164309 non-null  uint8
#  15  None                      164309 non-null  uint8
#  16  Other                     164309 non-null  uint8
#  17  Own                       164309 non-null  uint8
#  18  Rent                      164309 non-null  uint8
#  19  credit_card               164309 non-null  uint8
#  20  debt_consolidation        164309 non-null  uint8
#  21  educational               164309 non-null  uint8
#  22  home_improvement          164309 non-null  uint8
#  23  house                     164309 non-null  uint8
#  24  major_purchase            164309 non-null  uint8
#  25  medical                   164309 non-null  uint8
#  26  moving                    164309 non-null  uint8
#  27  other                     164309 non-null  uint8
#  28  renewable_energy          164309 non-null  uint8
#  29  small_business            164309 non-null  uint8
#  30  vacation                  164309 non-null  uint8
#  31  wedding                   164309 non-null  uint8
#  32  deliq                     164309 non-null  int64
#  33  10+ years                 164309 non-null  uint8
#  34  2 years                   164309 non-null  uint8
#  35  3 years                   164309 non-null  uint8
#  36  4 years                   164309 non-null  uint8
#  37  5 years                   164309 non-null  uint8
#  38  6 years                   164309 non-null  uint8
#  39  7 years                   164309 non-null  uint8
#  40  8 years                   164309 non-null  uint8
#  41  9 years                   164309 non-null  uint8
#  42  < 1 year                  164309 non-null  uint8
# dtypes: float64(3), int32(1), int64(5), object(1), uint8(33)
# memory usage: 17.1+ MB

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164309 entries, 0 to 164308
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Loan_Amount_Requested     164309 non-null  object
#  1   Annual_Income             164309 non-null  float64
#  2   Debt_To_Income            164309 non-null  float64
#  3   Inquiries_Last_6Mo        164309 non-null  int64
#  4   Months_Since_Deliquency   75930 non-null   float64
#  5   Number_Open_Accounts      164309 non-null  int64
#  6   Total_Accounts            164309 non-null  int64
#  7   Gender                    164309 non-null  int32
#  8   Interest_Rate             164309 non-null  int64
#  9   VERIFIED - income source  164309 non-null  uint8
#  10  not verified              164309 non-null  uint8
#  11  None                      164309 non-null  uint8
#  12  Other                     164309 non-null  uint8
#  13  Own                       164309 non-null  uint8
#  14  Rent                      164309 non-null  uint8
#  15  None                      164309 non-null  uint8
#  16  Other                     164309 non-null  uint8
#  17  Own                       164309 non-null  uint8
#  18  Rent                      164309 non-null  uint8
#  19  credit_card               164309 non-null  uint8
#  20  debt_consolidation        164309 non-null  uint8
#  21  educational               164309 non-null  uint8
#  22  home_improvement          164309 non-null  uint8
#  23  house                     164309 non-null  uint8
#  24  major_purchase            164309 non-null  uint8
#  25  medical                   164309 non-null  uint8
#  26  moving                    164309 non-null  uint8
#  27  other                     164309 non-null  uint8
#  28  renewable_energy          164309 non-null  uint8
#  29  small_business            164309 non-null  uint8
#  30  vacation                  164309 non-null  uint8
#  31  wedding                   164309 non-null  uint8
#  32  deliq                     164309 non-null  int64
#  33  10+ years                 164309 non-null  uint8
#  34  2 years                   164309 non-null  uint8
#  35  3 years                   164309 non-null  uint8
#  36  4 years                   164309 non-null  uint8
#  37  5 years                   164309 non-null  uint8
#  38  6 years                   164309 non-null  uint8
#  39  7 years                   164309 non-null  uint8
#  40  8 years                   164309 non-null  uint8
#  41  9 years                   164309 non-null  uint8
#  42  < 1 year                  164309 non-null  uint8
# dtypes: float64(3), int32(1), int64(5), object(1), uint8(33)
# memory usage: 17.1+ MB

# %%
train_set=train_set.drop('Interest_Rate',axis=1)

# %%
train_set['Loan_Amount_Requested']=train_set['Loan_Amount_Requested'].str.replace(',','').astype(int)
test_set['Loan_Amount_Requested']=test_set['Loan_Amount_Requested'].str.replace(',','').astype(int)

# %%
train_set_Y=np.array(train_set_Y)
train_set_Y=train_set_Y.ravel()

# %%
train_set.columns
# Out:
# Index(['Loan_Amount_Requested', 'Annual_Income', 'Debt_To_Income',
#        'Inquiries_Last_6Mo', 'Months_Since_Deliquency', 'Number_Open_Accounts',
#        'Total_Accounts', 'Gender', 'VERIFIED - income source', 'not verified',
#        'None', 'Other', 'Own', 'Rent', 'None', 'Other', 'Own', 'Rent',
#        'credit_card', 'debt_consolidation', 'educational', 'home_improvement',
#        'house', 'major_purchase', 'medical', 'moving', 'other',
#        'renewable_energy', 'small_business', 'vacation', 'wedding', 'deliq',
#        '10+ years', '2 years', '3 years', '4 years', '5 years', '6 years',
#        '7 years', '8 years', '9 years', '< 1 year'],
#       dtype='object')

# %%
model2=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.7, gamma=0.3, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.15, max_delta_step=0, max_depth=5,
              min_child_weight=1, monotone_constraints='()',
              n_estimators=100, n_jobs=0, num_parallel_tree=1,
              objective='multi:softprob', random_state=0, reg_alpha=0,
              reg_lambda=1, scale_pos_weight=None, subsample=1,
              tree_method='exact', validate_parameters=1, verbosity=None)
model2.fit(train_set,train_set_Y)
train_set_pred_xg=model2.predict(train_set)

test_set_pred_xg=model2.predict(test_set)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-4e67dd669157> in <module>
#       8               reg_lambda=1, scale_pos_weight=None, subsample=1,
#       9               tree_method='exact', validate_parameters=1, verbosity=None)
# ---> 10 model2.fit(train_set,train_set_Y)
#      11 train_set_pred_xg=model2.predict(train_set)
#      12
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     812                 'Please reshape the input data X into 2-dimensional matrix.')
#     813         self._features_count = X.shape[1]
# --> 814         train_dmatrix = DMatrix(X, label=training_labels, weight=sample_weight,
#     815                                 base_margin=base_margin,
#     816                                 missing=self.missing, nthread=self.n_jobs)
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread)
#     556             self.set_base_margin(base_margin)
#     557
# --> 558         self.feature_names = feature_names
#     559         self.feature_types = feature_types
#     560
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\xgboost\core.py in feature_names(self, feature_names)
#    1001
#    1002             if len(feature_names) != len(set(feature_names)):
# -> 1003                 raise ValueError('feature_names must be unique')
#    1004             if len(feature_names) != self.num_col():
#    1005                 msg = 'feature_names must have the same length as data'
#
# ValueError: feature_names must be unique

# %%
print(f1_score(train_set_Y, train_set_pred_xg, average='weighted'))
data1={'Loan_ID':test_set_loan,'Interest_Rate':test_set_pred_xg}
data1=pd.DataFrame(data1)
data1.to_csv('xg_jan.csv',index=False)
# Out:
# 0.5425195978230782

# %%
params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
    
}
model2=XGBClassifier()
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import accuracy_score
random_search=RandomizedSearchCV(model2,param_distributions=params,n_iter=5,scoring='f1_weighted',n_jobs=-1,cv=5,verbose=3)
random_search.fit(train_set,train_set_Y)
random_search.best_estimator_
